# %%
import pandas as pd
import numpy as np
import pygal

# %%
iris = pd.read_csv('Iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
pd.value_counts(iris['Species'], sort = True).sort_index()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.groupby('Species').mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
irissetosa = iris['Species'].map(lambda x: x.startswith('Iris-setosa'))
irisversicolor = iris['Species'].map(lambda x: x.startswith('Iris-versicolor'))
irisvirginica = iris['Species'].map(lambda x: x.startswith('Iris-virginica'))
listA = iris[irissetosa].loc[:, lambda df: ['SepalLengthCm']]
listB = iris[irisversicolor].loc[:, lambda df: ['SepalLengthCm']]
listC = iris[irisvirginica].loc[:, lambda df: ['SepalLengthCm']]
listD = iris[irissetosa].loc[:, lambda df: ['SepalWidthCm']]
listE = iris[irisversicolor].loc[:, lambda df: ['SepalWidthCm']]
listF = iris[irisvirginica].loc[:, lambda df: ['SepalWidthCm']]
listA
# Out:
#     SepalLengthCm
# 0             5.1
# 1             4.9
# 2             4.7
# 3             4.6
# 4             5.0
# 5             5.4
# 6             4.6
# 7             5.0
# 8             4.4
# 9             4.9
# 10            5.4
# 11            4.8
# 12            4.8
# 13            4.3
# 14            5.8
# 15            5.7
# 16            5.4
# 17            5.1
# 18            5.7
# 19            5.1
# 20            5.4
# 21            5.1
# 22            4.6
# 23            5.1
# 24            4.8
# 25            5.0
# 26            5.0
# 27            5.2
# 28            5.2
# 29            4.7
# 30            4.8
# 31            5.4
# 32            5.2
# 33            5.5
# 34            4.9
# 35            5.0
# 36            5.5
# 37            4.9
# 38            4.4
# 39            5.1
# 40            5.0
# 41            4.5
# 42            4.4
# 43            5.0
# 44            5.1
# 45            4.8
# 46            5.1
# 47            4.6
# 48            5.3
# 49            5.0

# %%
dot_chart = pygal.Dot(x_label_rotation=30)
dot_chart.title = 'V8 benchmark results'
dot_chart.x_labels = [map(float, range(4, 6))]
dot_chart.add('Iris-setosa', listA)
dot_chart.render()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-03233fa43a95> in <module>()
#       3 dot_chart.x_labels = [map(float, range(4, 6))]
#       4 dot_chart.add('Iris-setosa', listA)
# ----> 5 dot_chart.render()
#
# C:\Users\justin\Anaconda3\lib\site-packages\pygal\graph\public.py in render(self, is_unicode, **kwargs)
#      50     def render(self, is_unicode=False, **kwargs):
#      51         """Render the graph, and return the svg string"""
# ---> 52         self.setup(**kwargs)
#      53         svg = self.svg.render(
#      54             is_unicode=is_unicode, pretty_print=self.pretty_print)
#
# C:\Users\justin\Anaconda3\lib\site-packages\pygal\graph\base.py in setup(self, **kwargs)
#     215         if self._len < 3:
#     216             self.interpolate = None
# --> 217         self._draw()
#     218         self.svg.pre_render()
#     219
#
# C:\Users\justin\Anaconda3\lib\site-packages\pygal\graph\graph.py in _draw(self)
#     930         self._compute_margin()
#     931         self._decorate()
# --> 932         if self.series and self._has_data() and self._values:
#     933             self._plot()
#     934         else:
#
# C:\Users\justin\Anaconda3\lib\site-packages\pygal\graph\base.py in __getattribute__(self, name)
#      71                 self, 'state', None
#      72         ) is None or name not in self.state.__dict__:
# ---> 73             return super(BaseGraph, self).__getattribute__(name)
#      74         return getattr(self.state, name)
#      75
#
# C:\Users\justin\Anaconda3\lib\site-packages\pygal\util.py in __get__(self, obj, type_)
#     268         if obj is None:
#     269             return self
# --> 270         value = self.getter(obj)
#     271         if hasattr(obj, 'state'):
#     272             setattr(obj.state, self.__name__, value)
#
# C:\Users\justin\Anaconda3\lib\site-packages\pygal\graph\dot.py in _values(self)
#     110     def _values(self):
#     111         """Getter for series values (flattened)"""
# --> 112         return [abs(val) for val in super(Dot, self)._values if val != 0]
#     113
#     114     @cached_property
#
# C:\Users\justin\Anaconda3\lib\site-packages\pygal\graph\dot.py in <listcomp>(.0)
#     110     def _values(self):
#     111         """Getter for series values (flattened)"""
# --> 112         return [abs(val) for val in super(Dot, self)._values if val != 0]
#     113
#     114     @cached_property
#
# TypeError: bad operand type for abs(): 'str'
