# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pygal
from matplotlib.pyplot import cm
#import Librarys

# %%
iris = pd.read_csv('Iris.csv')
#import data

# %%
count_speices = pd.value_counts(iris['Species'], sort = True).sort_index()

# %%
# %matplotlib inline
from IPython.display import SVG, HTML

# %%
html_pygal = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
    <!-- ... -->
  </head>
  <body>
    <figure>
      {pygal_render}
    </figure>
  </body>
</html>
"""

# %%
bar = pygal.Bar()
bar.title = 'Iris count'
bar.x_labels = map (str,('Iris-setosa', 'Iris-versicolor', 'Iris-virginica'))
bar.add('Name', count_speices)
bar.render_to_file('bar_chart.svg')
HTML(html_pygal.format(pygal_render=bar.render()))
#bar graph comparing the speices
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2017-10-02--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff{background-color:rgba(249,249,249,1)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff path,#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff line,#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff rect,#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .graph{fill:rgba(0,0,0,.87)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff text.no_data{fill:rgba(0,0,0,1)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .title{fill:rgba(0,0,0,1)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .legends .legend text{fill:rgba(0,0,0,.87)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .axis .line{stroke:rgba(0,0,0,1)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .axis text.major{fill:rgba(0,0,0,1)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .axis.y .guides:hover .guide.line,#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .line-graph .axis.x .guides:hover .guide.line,#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .stackedline-graph .axis.x .guides:hover .guide.line,#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .ci{stroke:rgba(0,0,0,.87)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .reactive.active,#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .ci .reactive.active{stroke-width:1.5}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .series text{fill:rgba(0,0,0,1)}#chart-6f9bac02-ef16-448f-b3c9-3a1b13e0e9ff .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 15 ...

# %%
line = pygal.Line(stroke=False)
line.title = 'Petal Lengths'
line.add('Petal Length', iris['PetalLengthCm'])
line.add('Petal Width', iris['PetalWidthCm'])
line.render_to_file('scater.svg')
HTML(html_pygal.format(pygal_render=line.render()))
#scater plot looking at petal lengths
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-e535ebc7-5c54-4264-94f0-e33cd45b607d" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2017-10-02--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d{background-color:rgba(249,249,249,1)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d path,#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d line,#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d rect,#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .graph{fill:rgba(0,0,0,.87)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d text.no_data{fill:rgba(0,0,0,1)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .title{fill:rgba(0,0,0,1)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .legends .legend text{fill:rgba(0,0,0,.87)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .axis .line{stroke:rgba(0,0,0,1)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .axis text.major{fill:rgba(0,0,0,1)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .axis.y .guides:hover .guide.line,#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .line-graph .axis.x .guides:hover .guide.line,#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .stackedline-graph .axis.x .guides:hover .guide.line,#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .ci{stroke:rgba(0,0,0,.87)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .reactive.active,#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .ci .reactive.active{stroke-width:1.5}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .series text{fill:rgba(0,0,0,1)}#chart-e535ebc7-5c54-4264-94f0-e33cd45b607d .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 15 ...

# %%
hist = pygal.Bar()
hist.title = 'Petal Lengths'
hist.add('Petal Length', iris['PetalLengthCm'])
hist.add('Petal Width', iris['PetalWidthCm'])
hist.render_to_file('hist_chart.svg')
HTML(html_pygal.format(pygal_render=hist.render()))
#histogram graph comparing petal length and width
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-5708eb32-ae8f-45d9-8160-eae40909e10e" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2017-10-02--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-5708eb32-ae8f-45d9-8160-eae40909e10e{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-5708eb32-ae8f-45d9-8160-eae40909e10e{background-color:rgba(249,249,249,1)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e path,#chart-5708eb32-ae8f-45d9-8160-eae40909e10e line,#chart-5708eb32-ae8f-45d9-8160-eae40909e10e rect,#chart-5708eb32-ae8f-45d9-8160-eae40909e10e circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .graph{fill:rgba(0,0,0,.87)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e text.no_data{fill:rgba(0,0,0,1)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .title{fill:rgba(0,0,0,1)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .legends .legend text{fill:rgba(0,0,0,.87)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .axis .line{stroke:rgba(0,0,0,1)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .axis text.major{fill:rgba(0,0,0,1)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .axis.y .guides:hover .guide.line,#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .line-graph .axis.x .guides:hover .guide.line,#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .stackedline-graph .axis.x .guides:hover .guide.line,#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .ci{stroke:rgba(0,0,0,.87)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .reactive.active,#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .ci .reactive.active{stroke-width:1.5}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .series text{fill:rgba(0,0,0,1)}#chart-5708eb32-ae8f-45d9-8160-eae40909e10e .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 15 ...

# %%
color_dict = {'Iris-setosa':'blue', 'Iris-virginica':'red', 'Iris-versicolor':'black'}
#create a color dictionary

# %%
iris.plot(kind = "scatter", x = "SepalLengthCm", y = "SepalWidthCm", c = [color_dict[i] for i in iris['Species']])
plt.legend([color_dict])
#plot Sepal length by Sepal width
#blue is setosa. red versicolor, and black virginica
iris.plot(kind = "scatter", x = "PetalLengthCm", y = "PetalWidthCm", c = [color_dict[i] for i in iris['Species']])
plt.legend([color_dict])
#plot Petal length by Petal width
plt.show()

# %%
iris.plot(kind = "scatter", x = "SepalLengthCm", y = "PetalLengthCm", c = [color_dict[i] for i in iris['Species']])
plt.legend([color_dict])
iris.plot(kind = "scatter", x = "SepalWidthCm", y = "PetalWidthCm", c = [color_dict[i] for i in iris['Species']])
plt.legend([color_dict])
#Comparing length of sepal and petal in the first graph and width in the second
#blue is setosa. red versicolor, and black virginica
plt.show()

# %%
iris.groupby('Species').mean()
#group by the species and show mean of each number column
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
Iris_setosa = iris['Species'].map(lambda x: x.startswith('Iris-setosa'))
Iris_versicolor = iris['Species'].map(lambda x: x.startswith('Iris-versicolor'))
Iris_virginica = iris['Species'].map(lambda x: x.startswith('Iris-virginica'))
#makes a boolean that finds only one species name

# %%
IS = iris[Iris_setosa]
IVE = iris[Iris_versicolor]
IVI = iris[Iris_virginica]
#creates tables for each species

# %%
x = np.corrcoef(iris['PetalLengthCm'], iris['SepalLengthCm'])[0, 1]
#pearson corralation of lengths of petals and sepal in all the data
print('corralation of lengths of petals and sepals in all the data:',x)
x = np.corrcoef(iris['PetalLengthCm'], iris['PetalWidthCm'])[0, 1]
#pearson corralation of petal length and width in all the data
print('corralation of length and width of the petals in all the data:',x)
x = np.corrcoef(iris['PetalWidthCm'], iris['SepalWidthCm'])[0, 1]
#pearson corralation of width of petals and sepal in all the data
print('corralation of width of petals and sepals in all the data:',x)
x = np.corrcoef(iris['SepalLengthCm'], iris['SepalWidthCm'])[0, 1]
#pearson corralation of area of sepal and sepal+Petal in all the data
print('corralation of length and width of sepals in all the data:',x)
# Out:
# corralation of lengths of petals and sepals in all the data: 0.871754157305
# corralation of length and width of the petals in all the data: 0.962757097051
# corralation of width of petals and sepals in all the data: -0.356544089614
# corralation of length and width of sepals in all the data: -0.109369249951

# %%
heatmap, xedges, yedges = np.histogram2d(IS['PetalLengthCm'], IS['PetalWidthCm'])
#set up a heatmap of Iris setosa petal length by width
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.title('Heat Map of Petal Length and Width of Iris Setosa')
plt.xlabel('Petal Length in CM')
plt.ylabel('Petal Width in CM')
plt.imshow(heatmap, extent=extent, cmap=cm.viridis)
plt.colorbar(cmap=cm.viridis)
plt.show()
#the graph shows that the most common width and length is around 0.4 CM width and 1.2 CM Length

heatmap, xedges, yedges = np.histogram2d(IVE['PetalLengthCm'], IVE['PetalWidthCm'])
#set up a heatmap of Iris versicolor petal length by width
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.title('Heat Map of Petal Length and Width of Iris Versicolor')
plt.xlabel('Petal Length in CM')
plt.ylabel('Petal Width in CM')
plt.imshow(heatmap, extent=extent, cmap=cm.viridis)
plt.colorbar(cmap=cm.viridis)
plt.show()
#the graph shows the most common width and length is around 1.2 CM width and 4.4 length CM

heatmap, xedges, yedges = np.histogram2d(IVI['PetalLengthCm'], IVI['PetalWidthCm'])
#set up a heatmap of Iris virginicar petal length by width
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.title('Heat Map of Petal Length and Width of Iris Virginica')
plt.xlabel('Petal Length in CM')
plt.ylabel('Petal Width in CM')
plt.imshow(heatmap, extent=extent, cmap=cm.viridis)
plt.colorbar(cmap=cm.viridis)
plt.show()
#the graph shows the most common width and length is around 2.4 CM width and 5.5 CM length

# %%
count = pd.value_counts(iris['PetalLengthCm']).sort_index()
count
#create a count of petal lengths
# Out:
# 1.0     1
# 1.1     1
# 1.2     2
# 1.3     7
# 1.4    12
# 1.5    14
# 1.6     7
# 1.7     4
# 1.9     2
# 3.0     1
# 3.3     2
# 3.5     2
# 3.6     1
# 3.7     1
# 3.8     1
# 3.9     3
# 4.0     5
# 4.1     3
# 4.2     4
# 4.3     2
# 4.4     4
# 4.5     8
# 4.6     3
# 4.7     5
# 4.8     4
# 4.9     5
# 5.0     4
# 5.1     8
# 5.2     2
# 5.3     2
# 5.4     2
# 5.5     3
# 5.6     6
# 5.7     3
# 5.8     3
# 5.9     2
# 6.0     2
# 6.1     3
# 6.3     1
# 6.4     1
# 6.6     1
# 6.7     2
# 6.9     1
# Name: PetalLengthCm, dtype: int64

# %%
labels = ['1-1.9 cm', '3-3.9 cm', '4-4.9 cm', '5-5.9 cm', '6-6.9 cm']
sizes = [50, 11, 43, 35, 11]
fig1, ax1 = plt.subplots()
plt.title("Petal Lengths")
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal') 
#create a pie chart with a break down of each cm of petal length
plt.show()

# %%
pie_chart = pygal.Pie(half_pie = True)
pie_chart.title = 'Petal Lengths'
pie_chart.add('1-1.9 cm', 50)
pie_chart.add('3-3.9 cm', 11)
pie_chart.add('4-4.9 cm', 43)
pie_chart.add('5-5.9 cm', 35)
pie_chart.add('6-6.9 cm', 11)
#create a pie chart of the break down of petal length cms as a half pie
pie_chart.render_to_file('pie_chart.svg')
HTML(html_pygal.format(pygal_render=pie_chart.render()))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2017-10-02--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7{background-color:rgba(249,249,249,1)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 path,#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 line,#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 rect,#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .graph{fill:rgba(0,0,0,.87)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 text.no_data{fill:rgba(0,0,0,1)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .title{fill:rgba(0,0,0,1)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .axis .line{stroke:rgba(0,0,0,1)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .axis text.major{fill:rgba(0,0,0,1)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .axis.y .guides:hover .guide.line,#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .line-graph .axis.x .guides:hover .guide.line,#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .ci{stroke:rgba(0,0,0,.87)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .reactive.active,#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .ci .reactive.active{stroke-width:1.5}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .series text{fill:rgba(0,0,0,1)}#chart-8d80bcb9-081e-4af1-943a-f1e22f1aa1b7 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 15 ...

# %%
pie = pygal.Pie()
pie.title = 'Petal Lengths'
pie.add('1-1.9 cm', [1, 1, 2, 7, 12, 14, 7, 4, 2])
pie.add('3-3.9 cm', [1, 2, 2, 1, 1, 1, 3])
pie.add('4-4.9 cm', [5, 3, 4, 2, 4, 8, 3, 5, 4, 5])
pie.add('5-5.9 cm', [8, 2, 2, 2, 3, 6, 3, 3, 2])
pie.add('6-6.9 cm', [2, 3, 1, 1, 1, 2, 1])
#break down a pie chart into each 0.1 of a cm while still showing the full cm of petal length
pie.render_to_file('pie.svg')
HTML(html_pygal.format(pygal_render=pie.render()))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-e7371dd1-cd69-4459-ae8a-465f69812c73" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2017-10-02--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-e7371dd1-cd69-4459-ae8a-465f69812c73{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-e7371dd1-cd69-4459-ae8a-465f69812c73{background-color:rgba(249,249,249,1)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 path,#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 line,#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 rect,#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .graph{fill:rgba(0,0,0,.87)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 text.no_data{fill:rgba(0,0,0,1)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .title{fill:rgba(0,0,0,1)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .axis .line{stroke:rgba(0,0,0,1)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .axis text.major{fill:rgba(0,0,0,1)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .axis.y .guides:hover .guide.line,#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .line-graph .axis.x .guides:hover .guide.line,#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .ci{stroke:rgba(0,0,0,.87)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .reactive.active,#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .ci .reactive.active{stroke-width:1.5}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .series text{fill:rgba(0,0,0,1)}#chart-e7371dd1-cd69-4459-ae8a-465f69812c73 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 15 ...
